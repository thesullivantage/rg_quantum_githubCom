# %%
import qiskit
from qiskit import QuantumCircuit, execute
from qiskit import IBMQ
from qiskit.visualization import plot_histogram
import re
import json

TOKEN = "6c2d60af610ef14174e6c12a76418f6dfe81a4e1823d4867e629baf9e93811d9ddd459d492fb6d299de3d89d9ee0294664bf360cb4892fce4aa0e288dfb24922"
IBMQ.save_account(TOKEN)
provider = IBMQ.load_account()
provider = IBMQ.get_provider(group='open', project='main')


###########################################################
###################Lima################################
backend = provider.get_backend('ibmq_lima')
lima_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        lima_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        lima_dict[gate.name] = Xerror
    
print(json.dumps(lima_dict))
with open('ibmq_lima_LUT', 'w') as fp:
    json.dump(lima_dict, fp)
    

###########################################################
###################Santiago################################
backend = provider.get_backend('ibmq_santiago')
santiago_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        santiago_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        santiago_dict[gate.name] = Xerror
    
print(json.dumps(santiago_dict))
with open('ibmq_santiago_LUT', 'w') as fp:
    json.dump(santiago_dict, fp)


###########################################################
###################athens################################
backend = provider.get_backend('ibmq_athens')
athens_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        athens_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        athens_dict[gate.name] = Xerror
    
print(json.dumps(athens_dict))
with open('ibmq_athens_LUT', 'w') as fp:
    json.dump(athens_dict, fp)
    
###########################################################
###################yorktown################################
backend = provider.get_backend('ibmq_5_yorktown')
yorktown_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        yorktown_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        #print('This is a Pauli-X gate')
        #print(gate.name)
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        yorktown_dict[gate.name] = Xerror
    
print(json.dumps(yorktown_dict))
with open('ibmq_yorktown_LUT', 'w') as fp:
    json.dump(yorktown_dict, fp)
    
###########################################################
###################belem################################
backend = provider.get_backend('ibmq_belem')
belem_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        belem_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        belem_dict[gate.name] = Xerror
    
print(json.dumps(belem_dict))
with open('ibmq_belem_LUT', 'w') as fp:
    json.dump(belem_dict, fp)
    
###########################################################
###################armonk################################
backend = provider.get_backend('ibmq_armonk')
armonk_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        armonk_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        armonk_dict[gate.name] = Xerror
    
print(json.dumps(armonk_dict))
with open('ibmq_armonk_LUT', 'w') as fp:
    json.dump(armonk_dict, fp)
    

###########################################################
###################quito################################
backend = provider.get_backend('ibmq_quito')
quito_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        quito_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        quito_dict[gate.name] = Xerror
    
print(json.dumps(quito_dict))
with open('ibmq_quito_LUT', 'w') as fp:
    json.dump(quito_dict, fp)
    
###########################################################
###################melbourne################################
backend = provider.get_backend('ibmq_16_melbourne')
melbourne_dict = {}
for gate in backend.properties().gates:
    if re.search("^cx.*[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        CNOTerror = symbols[len(symbols) - 1]
        CNOTerror = CNOTerror[0:len(CNOTerror)-1]
        melbourne_dict[gate.name] = CNOTerror
    elif re.search("^x[0-9]", gate.name):
        symbols = str(gate.parameters[0]).split()
        Xerror = symbols[len(symbols) - 1]
        Xerror = Xerror[0:len(Xerror)-1]
        melbourne_dict[gate.name] = Xerror
    
print(json.dumps(melbourne_dict))
with open('ibmq_melbourne_LUT', 'w') as fp:
    json.dump(melbourne_dict, fp)
# Out:
# configrc.store_credentials:WARNING:2021-04-18 17:36:39,256: Credentials already present. Set overwrite=True to overwrite.
# ibmqfactory.load_account:WARNING:2021-04-18 17:36:39,412: Credentials are already in use. The existing account in the session will be replaced.
# {"x0": "0.0002571926872593804", "x1": "0.0002079949554833629", "x2": "0.00024905554343175547", "x3": "0.00024910066100338217", "x4": "0.0007508844844303335", "cx4_3": "0.01773726893233915", "cx3_4": "0.01773726893233915", "cx0_1": "0.0060148979765101696", "cx1_0": "0.0060148979765101696", "cx3_1": "0.007996195448644994", "cx1_3": "0.007996195448644994", "cx2_1": "0.0057488371619371925", "cx1_2": "0.0057488371619371925"}
# ...
